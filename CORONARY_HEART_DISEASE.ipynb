# %% [markdown]
# <a href="https://colab.research.google.com/github/33Surya66/Coronary-Heart-Disease/blob/main/CORONARY_HEART_DISEASE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import os
import warnings
df = pd.read_csv('/content/heart.csv')
df.head(300)
# Out:
#      gender  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0      Male   39          4              0           0       0
# 1    Female   46          2              0           0       0
# 2      Male   48          1              1          20       0
# 3    Female   61          3              1          30       0
# 4    Female   46          3              1          23       0
# ..      ...  ...        ...            ...         ...     ...
# 295    Male   41          2              1          40       0
# 296    Male   51          3              0           0       0
# 297  Female   34          3              1          10       0
# 298    Male   41          2              0           0       0
# 299  Female   62          2              0           0       1
#
#      prevalentStroke  prevalentHyp  heartRate  totChol  sysBP  diaBP    BMI  \
# 0                  0             0         80      195  106.0   70.0  26.97
# ...

# %%
df.groupby(['gender', 'age','BMI']).mean()
# Out:
#                   education  currentSmoker  cigsPerDay  BPMeds  \
# gender age BMI
# Female 34  21.50        3.0            1.0        10.0     0.0
#            23.88        4.0            0.0         0.0     0.0
#        35  22.00        2.0            0.0         0.0     0.0
#        36  20.41        3.0            1.0        20.0     0.0
#            22.53        1.0            1.0         3.0     0.0
# ...                     ...            ...         ...     ...
# Male   65  24.04        4.0            0.0         0.0     0.0
#            29.35        1.0            1.0        15.0     0.0
#        66  29.29        3.0            0.0         0.0     0.0
#        67  25.95        4.0            0.0         0.0     0.0
#        68  30.28        1.0            0.0         0.0     0.0
#
#                   prevalentStroke  prevalentHyp  heartRate  totChol  sysBP  \
# gender age BMI
# Female 34  21.50              0.0           0.0       75.0    206.0  101.0
# ...

# %%
df.describe()
# Out:
#               age   education  currentSmoker  cigsPerDay      BPMeds  \
# count  300.000000  300.000000      300.00000  300.000000  300.000000
# mean    49.586667    2.026667        0.46000    9.326667    0.040000
# std      8.974275    1.081598        0.49923   13.369209    0.196287
# min     34.000000    1.000000        0.00000    0.000000    0.000000
# 25%     42.000000    1.000000        0.00000    0.000000    0.000000
# 50%     48.500000    2.000000        0.00000    0.000000    0.000000
# 75%     57.000000    3.000000        1.00000   20.000000    0.000000
# max     68.000000    4.000000        1.00000   70.000000    1.000000
#
#        prevalentStroke  prevalentHyp   heartRate     totChol       sysBP  \
# count       300.000000    300.000000  300.000000  300.000000  300.000000
# mean          0.003333      0.310000   75.556667  235.020000  132.548333
# std           0.057735      0.463266   11.659328   46.593951   22.134248
# ...

# %%
sb.boxplot(x=df['age'])
# Out:
# <Axes: xlabel='age'>

# %%
df.corr()['TenYearCHD'].sort_values()
# Out:
# education         -0.051175
# heartRate         -0.042992
# currentSmoker     -0.028452
# prevalentStroke   -0.028312
# BPMeds             0.029290
# cigsPerDay         0.033551
# totChol            0.141870
# diaBP              0.175803
# BMI                0.189557
# sysBP              0.208062
# age                0.218546
# prevalentHyp       0.219370
# TenYearCHD         1.000000
# Name: TenYearCHD, dtype: float64

# %%
df.isnull().sum()
# Out:
# gender             0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# heartRate          0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# TenYearCHD         0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
#sex
le = LabelEncoder()
le.fit(df.gender.drop_duplicates())
df.gender = le.transform(df.gender)
# smoker or not
le.fit(df.currentSmoker.drop_duplicates())
df.currentSmoker = le.transform(df.currentSmoker)

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = df.corr()
sb.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sb.diverging_palette(290,12,as_cmap=True),
            square=True, ax=ax)
# Out:
# <ipython-input-45-f7fa4e3d3cb2>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sb.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sb.diverging_palette(290,12,as_cmap=True),
# <Axes: >

# %%
f= plt.figure(figsize=(12,5))

ax=f.add_subplot(121)
sb.distplot(df[(df.currentSmoker == 1)]["age"],color='c',ax=ax)
ax.set_title('Distribution of age for smokers')

ax=f.add_subplot(122)
sb.distplot(df[(df.currentSmoker == 0)]['age'],color='b',ax=ax)
ax.set_title('Distribution of age for non-smokers')
# Out:
# <ipython-input-46-d997cc5ee2bf>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df[(df.currentSmoker == 1)]["age"],color='c',ax=ax)
# <ipython-input-46-d997cc5ee2bf>:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sb.pairplot(df,hue="TenYearCHD")

# %%
sb.catplot(x="currentSmoker", kind="count",hue = 'gender', palette="Spectral", data=df)

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for women")
sb.boxplot(y="TenYearCHD", x="age", data =  df[(df.TenYearCHD == 1)] , orient="h", palette = 'magma')
# Out:
# <Axes: title={'center': 'Box plot for women'}, xlabel='age', ylabel='TenYearCHD'>

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for men")
sb.boxplot(y="TenYearCHD", x="age", data =  df[(df.TenYearCHD == 0)] , orient="h", palette = 'Spectral')
# Out:
# <Axes: title={'center': 'Box plot for men'}, xlabel='age', ylabel='TenYearCHD'>

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution of age")
ax = sb.distplot(df["age"], color = 'c')
# Out:
# <ipython-input-51-33e90dd28257>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sb.distplot(df["age"], color = 'c')

# %%
sb.catplot(x="currentSmoker", kind="count", palette="Spectral", data=df)

# %%
sb.lmplot(x="cigsPerDay", y="TenYearCHD", hue="currentSmoker", data=df, palette = 'inferno_r')
ax.set_title('Smokers and non-smokers')
# Out:
# Text(0.5, 1.0, 'Smokers and non-smokers')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix as conf
from sklearn.metrics import accuracy_score as accuracy

# %%
X = df.drop('TenYearCHD',axis=1)
y = df['TenYearCHD']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-947fee5b52ea> in <cell line: 1>()
# ----> 1 X = df.drop('TenYearCHD',axis=1)
#       2 y = df['TenYearCHD']
#
# NameError: name 'df' is not defined

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
X_ros, y_ros = smote.fit_resample(X, y)
ros_chd_plot=y_ros.value_counts().plot(kind='bar')
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X_ros,y_ros,test_size=0.2,random_state=42)
X_train.head()
# Out:
#      gender  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 412       1   45          2              1          23       0
# 25        1   47          4              1          20       0
# 220       0   36          2              1          20       0
# 396       0   52          1              0           8       0
# 231       0   59          2              0           0       0
#
#      prevalentStroke  prevalentHyp  heartRate  totChol      sysBP      diaBP  \
# 412                0             0         80      249  130.47454  87.309861
# 25                 0             0         62      294  102.00000  68.000000
# 220                0             0         50      150  117.50000  77.500000
# 396                0             0         80      286  138.00000  83.503084
# 231                0             0         80      310  129.00000  70.000000
#
#            BMI
# 412  28.729805
# 25   24.180000
# 220  23.710000
# 396  24.884385
# 231  23.290000

# %%
from sklearn.metrics import classification_report
def my_confusion_matrix(y_test, y_pred, plt_title):
    cm=conf(y_test, y_pred)
    print(classification_report(y_test, y_pred))
    sb.heatmap(cm, annot=True, fmt='g', cbar=False, cmap='BuPu')
    plt.xlabel('Predicted Values')
    plt.ylabel('Actual Values')
    plt.title(plt_title)
    plt.show()
    return cm

# %% [markdown]
# ##**Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions = model.predict(X_test)
from sklearn.metrics import classification_report, accuracy_score,confusion_matrix

print('Classificatio report',classification_report(y_test,predictions))
print('********')

print('Accuracy with Logistic Regression: ',accuracy_score(y_test,predictions))
print('********')

print('The confusion matrix',my_confusion_matrix(y_test,predictions,'Logistic Regression CM'))
# Out:
# Classificatio report               precision    recall  f1-score   support
#
#            0       0.62      0.70      0.66        44
#            1       0.72      0.64      0.68        53
#
#     accuracy                           0.67        97
#    macro avg       0.67      0.67      0.67        97
# weighted avg       0.68      0.67      0.67        97
#
# ********
# Accuracy with Logistic Regression:  0.6701030927835051
# ********
#               precision    recall  f1-score   support
#
#            0       0.62      0.70      0.66        44
#            1       0.72      0.64      0.68        53
#
#     accuracy                           0.67        97
#    macro avg       0.67      0.67      0.67        97
# weighted avg       0.68      0.67      0.67        97
# The confusion matrix [[31 13]
#  [19 34]]

# %% [markdown]
# ##**SVM**

# %%
from sklearn.svm import SVC
SVCClf = SVC(kernel = 'rbf')
SVCClf.fit(X, y)
# Out:
# SVC()

# %%
Y_pred = SVCClf.predict(X_test)

# %%
acs = accuracy_score(y_test, Y_pred)
acs
# Out:
# 0.4536082474226804

# %%
cm= conf(y_test, Y_pred)
cm
# Out:
# array([[44,  0],
#        [53,  0]])

# %% [markdown]
# ##**Decision Tree**

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

# %%
Y_pred = clf.predict(X_test)

# %%
acs = accuracy_score(y_test, Y_pred)
acs
# Out:
# 0.7731958762886598

# %%
cm= conf(y_test, Y_pred)
cm
# Out:
# array([[44,  0],
#        [22, 31]])

# %% [markdown]
# ## **Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=0)
clf.fit(X, y)
# Out:
# RandomForestClassifier(random_state=0)

# %%
Y_pred = clf.predict(X_test)
acs = accuracy_score(y_test, Y_pred)
acs
# Out:
# 0.6597938144329897

# %%
cm= conf(y_test, Y_pred)
cm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ec95a3f1b858> in <cell line: 1>()
# ----> 1 cm= conf(y_test, y_pred)
#       2 cm
#       3 cd = ConfusionMatrixDisplay(confusion_matrix = cn, display_labels=['Studying','Enrolled', 'Dropout'])
#       4 cd.plot()
#
# NameError: name 'conf' is not defined
